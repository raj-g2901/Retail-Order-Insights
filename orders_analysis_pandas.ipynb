# %% [markdown]
# # Retail Order Insights

# %% [markdown]
# ### Importing Necessary Libraries

# %%
#import libraries
import kaggle
import pandas as pd
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv

# %% [markdown]
# ### Extract CSV file from zipped file

# %%
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip') 
zip_ref.extractall() # extract file to dir
zip_ref.close() # close file

# %% [markdown]
# ### Evaluating 'Ship Mode' column

# %%
#Here, we check for missing values for ship mode column and handle them by filling or dropping rows to ensure our dataset is clean.
df['Ship Mode'].unique()

# %%
#read data from the file and handle bad values 
df = pd.read_csv('orders.csv',na_values=['Not Available','unknown']) # Make cells NaN where 'Not Available','unknown' is present
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
# Checking if 'Not Available','unknown' are handled
df['Ship Mode'].unique()

# %% [markdown]
# ### Make the headings lower case and replace space with underscore

# %%
df.columns=df.columns.str.lower()
# replace space with underscore
df.columns=df.columns.str.replace(' ','_') # Alt way - df.rename(columns={'Order Id':'order_id', 'City':'city'})
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# ### Derive new discount, sale price and profit column

# %%
df['discount']=df['list_price']*df['discount_percent']*.01
df['sale_price']= df['list_price']-df['discount']
df['profit']=df['sale_price']-df['cost_price']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %% [markdown]
# ### convert order date from object data type to datetime

# %%
df['order_date']=pd.to_datetime(df['order_date'],format="%Y-%m-%d")
df['order_date']

# %% [markdown]
# ### Dropping unneccesary columns- 'list_price','cost_price','discount_percent'

# %%
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)

# %% [markdown]
# ### Loading Data into MySQL using `SQLAlchemy` engine

# %%
#import pandas as pd
import sqlalchemy as sal

username = 'root'
password = '12345678'
host = 'localhost'
database = 'my_db'  # database name 

# Create a SQLAlchemy engine for MySQL
engine = sal.create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}/{database}')

# Create a connection
conn = engine.connect()

# %% [markdown]
# We use the `to_sql` function to load our cleaned and prepared dataset into a MySQL table.

# %%
# load the data into MySQL
df.to_sql('df_orders', con=conn, index=False, if_exists='append') # df_orders is Table name
# here we are appending and not replacing because by deaful Pandas creates Table with highest value data types. which is not a good practice.
# So, we will create the database and table in MYSQL by ourselves of same names. And then append through pandas.

# %% [markdown]
# Close the connection

# %%
conn.close()
